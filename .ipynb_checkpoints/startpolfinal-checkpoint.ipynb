# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
df_test = pd.read_csv('Empty_part.csv')
df_train = pd.read_csv('Training_wells.csv')

# %%
df_test = df_test.drop(['Well'], axis=1)
df_train = df_train.drop(['Well'], axis=1)

# %%
print(df_train)
print(df_test)
# Out:
#        X    Y     NTG
# 0    201  907  0.2006
# 1    201  914  0.3624
# 2    201  924  0.4381
# 3    202  922  0.4289
# 4    202  925  0.4021
# ..   ...  ...     ...
# 133  245  908  0.2719
# 134  245  911  0.3780
# 135  245  923  0.4239
# 136  246  905  0.4900
# 137  246  923  0.3667
#
# [138 rows x 3 columns]
#         X    Y
# 0     201  901
# 1     201  902
# 2     201  903
# 3     201  904
# 4     201  905
# ...   ...  ...
# 1237  246  926
# 1238  246  927
# 1239  246  928
# 1240  246  929
# 1241  246  930
#
# [1242 rows x 2 columns]

# %%
df = df_train
x = df['X']
y = df['Y']

fig, ax = plt.subplots()

ax.scatter(x, y,c = 'red')    #  цвет точек

df = df_test
x = df['X']
y = df['Y']

ax.scatter(x, y, c = 'green')    #  цвет точек
ax.set_facecolor('black')

fig.set_figwidth(10)     #  ширина и
fig.set_figheight(10)    #  высота "Figure"

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D


dx = 0.01; dy = 0.01
x = np.arange(-2.0,2.0,dx)
y = np.arange(-2.0,2.0,dy)
X,Y = np.meshgrid(x,y)
print(X)
def f(x,y):
    return (1 - y**5 + x**5)*np.exp(-x**2-y**2)

C = plt.contour(X,Y,f(X,Y),8,colors='black')
plt.contourf(X,Y,f(X,Y),8)
plt.clabel(C, inline=1, fontsize=10)
plt.show()
# Out:
# [[-2.   -1.99 -1.98 ...  1.97  1.98  1.99]
#  [-2.   -1.99 -1.98 ...  1.97  1.98  1.99]
#  [-2.   -1.99 -1.98 ...  1.97  1.98  1.99]
#  ...
#  [-2.   -1.99 -1.98 ...  1.97  1.98  1.99]
#  [-2.   -1.99 -1.98 ...  1.97  1.98  1.99]
#  [-2.   -1.99 -1.98 ...  1.97  1.98  1.99]]

# %%
df = df_train
x = df['X']
y = df['Y']
z =df['NTG']
print(z)
x,y,z = np.meshgrid(x,y,z)
fig = plt.figure()
ax = Axes3D(fig)

ax.plot_surface(x,y,z,rstride=1, cstride=1,cmap=plt.cm.hot)

plt.show()
# Out:
# 0      0.2006
# 1      0.3624
# 2      0.4381
# 3      0.4289
# 4      0.4021
#         ...
# 133    0.2719
# 134    0.3780
# 135    0.4239
# 136    0.4900
# 137    0.3667
# Name: NTG, Length: 138, dtype: float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-c8edb7b791d8> in <module>
#       8 ax = Axes3D(fig)
#       9
# ---> 10 ax.plot_surface(x,y,z,rstride=1, cstride=1,cmap=plt.cm.hot)
#      11
#      12 plt.show()
#
# c:\users\guben\pycharmprojects\pythonproject\venv\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1554
#    1555         if Z.ndim != 2:
# -> 1556             raise ValueError("Argument Z must be 2-dimensional.")
#    1557         if np.any(np.isnan(Z)):
#    1558             cbook._warn_external(
#
# ValueError: Argument Z must be 2-dimensional.
